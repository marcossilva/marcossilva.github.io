# %% [markdown]
# ## User-Product Recomendation
#
# ![image.png](attachment:image.png)
#
# Given a bipartite graph where we connect the users to the products they've interacted it's possible to stablish both projections U and V and group similar types of users (Community detection) and similar types of itens (Community detection) and mapping these Aggregated communities on both sides it's possible to stablish a link prdiction task
